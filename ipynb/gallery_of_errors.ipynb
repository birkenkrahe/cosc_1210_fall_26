# %% [markdown]
# ## A Gallery of Errors

# %% [markdown]
# ### SyntaxError

# %%
# SyntaxError - Python cannot parse the code
print("hello)
# Out:
#   Cell In[1], line 2
#     print("hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### IndentationError

# %%
# IndentationError - unexpected indent
print("hello", end=" ")
  print("world")
# Out:
#   Cell In[2], line 3
#     print("world")
#     ^
# IndentationError: unexpected indent

# %%
print("hello", end=" ")
print("world")
# Out:
# hello world

# %% [markdown]
# ### NameError

# %%
# NameError - variable is used before it was defined
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # NameError - variable is used before it was defined
# ----> 2 print(age)
#
# NameError: name 'age' is not defined

# %%
age = 25
print(age)
# Out:
# 25

# %% [markdown]
# ### TypeError

# %%
# TypeError - wrong type for the operation
print('3' + 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # TypeError - wrong type for the operation
# ----> 2 print('3' + 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('3' + str(3)) # concatenating two strings
print(3 + 3) # adding two integers
# Out:
# 33
# 6

# %% [markdown]
# ### ValueError

# %%
# ValueError - right type, but the value cannot be converted
int("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # ValueError - right type, but the value cannot be converted
# ----> 2 int("hello")
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
int("444")
# Out:
# 444

# %% [markdown]
# ### ZeroDivisionError

# %%
# ZeroDivisionError - dividing by zero is not defined
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # ZeroDivisionError - dividing by zero is not defined
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# There's no fix but you can build guardrails around operations that might return this error, using the `try...except` command in Python.

# %% [markdown]
# ### ModuleNotFoundError

# %%
### ModuleNotFoundError - module does not exist or is not installed
import pandaemonium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 ### ImportError - module does not exist or is not installed
# ----> 2 import pandaemonium
#
# ModuleNotFoundError: No module named 'pandaemonium'

# %% [markdown]
# ### IndexError

# %%
# IndexError - index goes beyond the length of the list
x = [10,20,30]
len(x)      # notice that Python starts numbering at 0
# Out:
# 3

# %%
print(x[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(x[3])
#
# IndexError: list index out of range

# %%
print(x[len(x)-1])
# Out:
# 3

# %% [markdown]
# ### Semantic error

# %%
# Semantic error - runs, but gives the wrong answer
import math

radius = 5
area = 2 * math.pi * radius # wrong formula!

print(area)
# Out:
# 31.41592653589793

# %%
area = math.pi * radius**2
print(area)
# Out:
# 78.53981633974483
